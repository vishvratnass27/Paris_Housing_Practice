# %% [markdown]
# # Practice Dataset - 1 (Paris Housing )
# This dataset contains numeric attributes related to house details in an urban setting in Paris, including square meters, room count, yard and pool presence, floor count, zip code, neighborhood exclusivity, previous owner count, construction year, new construction status, storm protection, basement, attic, garage size, storage room, guest room, and house price.

# %% [markdown]
# # Importing Necessary Libraries:
#
# This section imports the essential Python libraries for data analysis and visualization, including NumPy, Pandas, Seaborn, and Matplotlib.

# %%
#importing necessary libraries

import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the Dataset:
#
# The code reads a dataset named "ParisHousing.csv" and stores it in a Pandas DataFrame called paris_df. The dataset likely contains information about housing in Paris.

# %%
#Reading the dataset

paris_df = pd.read_csv("ParisHousing.csv")
paris_df
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %% [markdown]
# # Shape of the Dataset:
#
# paris_df.shape is used to find and display the total number of rows and columns in the dataset. It tells you how large your dataset is.

# %%
# Shape of the dataset:Total no. of rows and columns

paris_df.shape
# Out:
# (10000, 17)

# %% [markdown]
# # Information About the Dataset:
#
# paris_df.info() provides information about the DataFrame, including data types of each column and the number of non-null values. It's useful for understanding the structure of the dataset.

# %%
#Information about a DataFrame including the index dtype and column dtypes, non-null values

paris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   squareMeters       10000 non-null  int64
#  1   numberOfRooms      10000 non-null  int64
#  2   hasYard            10000 non-null  int64
#  3   hasPool            10000 non-null  int64
#  4   floors             10000 non-null  int64
#  5   cityCode           10000 non-null  int64
#  6   cityPartRange      10000 non-null  int64
#  7   numPrevOwners      10000 non-null  int64
#  8   made               10000 non-null  int64
#  9   isNewBuilt         10000 non-null  int64
#  10  hasStormProtector  10000 non-null  int64
#  11  basement           10000 non-null  int64
#  12  attic              10000 non-null  int64
#  13  garage             10000 non-null  int64
#  14  hasStorageRoom     10000 non-null  int64
#  15  hasGuestRoom       10000 non-null  int64
# ...

# %% [markdown]
# # Checking for Missing Values:
#
# paris_df.isnull().sum() counts and displays the number of missing values (NaN) in each column of the DataFrame. It helps identify missing data.

# %%
paris_df.isnull().sum()
# Out:
# squareMeters         0
# numberOfRooms        0
# hasYard              0
# hasPool              0
# floors               0
# cityCode             0
# cityPartRange        0
# numPrevOwners        0
# made                 0
# isNewBuilt           0
# hasStormProtector    0
# basement             0
# attic                0
# garage               0
# hasStorageRoom       0
# hasGuestRoom         0
# price                0
# dtype: int64

# %% [markdown]
# # Statistical Analysis of Data:
#
# paris_df.describe() calculates basic statistics (like mean, standard deviation, etc.) for the numeric columns in the DataFrame. It provides an overview of the data's distribution.

# %%
#Statistical analysis of data

paris_df.describe()
# Out:
#        squareMeters  numberOfRooms       hasYard       hasPool        floors  \
# count   10000.00000   10000.000000  10000.000000  10000.000000  10000.000000
# mean    49870.13120      50.358400      0.508700      0.496800     50.276300
# std     28774.37535      28.816696      0.499949      0.500015     28.889171
# min        89.00000       1.000000      0.000000      0.000000      1.000000
# 25%     25098.50000      25.000000      0.000000      0.000000     25.000000
# 50%     50105.50000      50.000000      1.000000      0.000000     50.000000
# 75%     74609.75000      75.000000      1.000000      1.000000     76.000000
# max     99999.00000     100.000000      1.000000      1.000000    100.000000
#
#            cityCode  cityPartRange  numPrevOwners         made    isNewBuilt  \
# count  10000.000000   10000.000000   10000.000000  10000.00000  10000.000000
# mean   50225.486100       5.510100       5.521700   2005.48850      0.499100
# ...

# %%
paris_df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %% [markdown]
# # Performing Correlation Analysis:
#
# The code calculates the correlation between numeric variables using paris_df.corr(). The result is a correlation matrix that measures the relationships between variables. sns.heatmap() from Seaborn creates a heatmap visualization of this matrix, making it easier to understand variable relationships.

# %%
#Perform correlation to visualize relationships between variables

correlation = paris_df.corr()
correlation
# Out:
#                    squareMeters  numberOfRooms   hasYard   hasPool    floors  \
# squareMeters           1.000000       0.009573 -0.006650 -0.005594  0.001109
# numberOfRooms          0.009573       1.000000 -0.011240  0.017015  0.022244
# hasYard               -0.006650      -0.011240  1.000000  0.015514 -0.000883
# hasPool               -0.005594       0.017015  0.015514  1.000000 -0.004006
# floors                 0.001109       0.022244 -0.000883 -0.004006  1.000000
# cityCode              -0.001541       0.009040  0.006760  0.008072  0.002207
# cityPartRange          0.008758       0.008340  0.005023  0.014613 -0.004921
# numPrevOwners          0.016619       0.016766  0.004279 -0.006848  0.002463
# made                  -0.007207       0.003978  0.002214  0.001894  0.005022
# isNewBuilt            -0.010667      -0.002865 -0.008370  0.000188  0.002458
# hasStormProtector      0.007480      -0.001656 -0.007598 -0.001001 -0.008566
# ...

# %%
sns.heatmap(data=correlation,linewidth=4, cmap='Paired')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Identifying a Relationship:
#
# plt.figure(figsize=(10,8)) sets the size of the plot.
# plt.plot(paris_df['squareMeters'], paris_df['price']) plots a graph showing the relationship between the 'squareMeters' and 'price' columns in your dataset.

# %%
# Identifying relationship b/w squaremeters and price columns for feature selection

plt.figure(figsize=(10,8))
plt.plot(paris_df['squareMeters'], paris_df['price'])

# %% [markdown]
# # Feature Selection:
#
# paris_df = paris_df.drop(columns=['cityPartRange','numPrevOwners','cityCode']) removes certain columns from the DataFrame. It appears to be part of a feature selection process.

# %%
#drop the feature
paris_df = paris_df.drop(columns=['cityPartRange','numPrevOwners','cityCode'])

# %%
paris_df
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  made  isNewBuilt  \
# 0            75523              3        0        1      63  2005           0
# 1            80771             39        1        1      98  2015           1
# 2            55712             58        0        1      19  2021           0
# 3            32316             47        0        0       6  2012           0
# 4            70429             19        1        1      90  1990           1
# ...            ...            ...      ...      ...     ...   ...         ...
# 9995          1726             89        0        1       5  2009           0
# 9996         44403             29        1        1      12  1990           0
# 9997         83841              3        0        0      69  2005           1
# 9998         59036             70        0        0      96  2010           0
# 9999          1440             84        0        0      49  1994           1
#
# ...

# %% [markdown]
# # Machine Learning Model Setup:
#
# from sklearn.ensemble import RandomForestRegressor imports a machine learning model called RandomForestRegressor.
#
# from sklearn.model_selection import train_test_split is used to split the data into training and testing sets.
#
# reg = RandomForestRegressor() creates an instance of the RandomForestRegressor model.
#
# X and y are defined as the input features and target variable, respectively.
#
# X_train, X_test, y_train, and y_test are created by splitting the data into training and testing sets.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
reg = RandomForestRegressor()

# %%
X = paris_df
y = paris_df['price']

# %%
X
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  made  isNewBuilt  \
# 0            75523              3        0        1      63  2005           0
# 1            80771             39        1        1      98  2015           1
# 2            55712             58        0        1      19  2021           0
# 3            32316             47        0        0       6  2012           0
# 4            70429             19        1        1      90  1990           1
# ...            ...            ...      ...      ...     ...   ...         ...
# 9995          1726             89        0        1       5  2009           0
# 9996         44403             29        1        1      12  1990           0
# 9997         83841              3        0        0      69  2005           1
# 9998         59036             70        0        0      96  2010           0
# 9999          1440             84        0        0      49  1994           1
#
# ...

# %%
y
# Out:
# 0       7559081.5
# 1       8085989.5
# 2       5574642.1
# 3       3232561.2
# 4       7055052.0
#           ...
# 9995     176425.9
# 9996    4448474.0
# 9997    8390030.5
# 9998    5905107.0
# 9999     146708.4
# Name: price, Length: 10000, dtype: float64

# %% [markdown]
# # Model Training and Evaluation:
#
# reg.fit(X_train, y_train) trains the RandomForestRegressor model.
# reg.score(X_train, y_train) calculates the model's accuracy on the training data.
# evaluate() is defined to evaluate the model's performance, calculating metrics like average error and accuracy.

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
reg.score(X_train,y_train)
# Out:
# 0.9999999582234405

# %% [markdown]
# # Evaluating Model Performance:
#
# evaluate(reg, X_train, y_train) and evaluate(reg, X_test, y_test) are called to evaluate the model's performance on the training and testing datasets, respectively.

# %%
def evaluate(model, X, y):
    predictions = model.predict(X)
    errors = abs(predictions - y)
    mape = 100 * np.mean(errors / y)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy

# %%
# Evaluating the model performance

evaluate(reg,X_train,y_train)
# Out:
# Model Performance
# Average Error: 444.3922 degrees.
# Accuracy = 99.97%.
# 99.97009119041563

# %%
evaluate(reg,X_test,y_test)
# Out:
# Model Performance
# Average Error: 1140.3446 degrees.
# Accuracy = 99.89%.
# 99.89368460355074

# %% [markdown]
# # Feature Importance:
#
# feature_importance = reg.feature_importances_ calculates the importance of each feature in the model.
# The code then creates a DataFrame called paris_df to store the feature names and their importance scores.

# %%
feature_importance = reg.feature_importances_

# %%
for i in range(0,len(feature_importance),1):
    new_array = zip(X.columns,feature_importance)

# %%
paris_df = pd.DataFrame(new_array)

# %% [markdown]
# # Sorting Feature Importance:
#
# paris_df.sort_values(by=1, ascending=False) sorts the features by their importance score in descending order, helping identify which features are most important in predicting the target variable.

# %%
#Sorting feature importance

paris_df.sort_values(by=1,ascending=False)
# Out:
#                     0             1
# 13              price  6.561179e-01
# 0        squareMeters  3.438817e-01
# 9               attic  5.456011e-08
# 8            basement  5.176073e-08
# 5                made  5.081553e-08
# 1       numberOfRooms  5.032316e-08
# 4              floors  5.022423e-08
# 10             garage  4.964984e-08
# 12       hasGuestRoom  4.009628e-08
# 3             hasPool  1.315251e-08
# 6          isNewBuilt  1.266701e-08
# 11     hasStorageRoom  1.265582e-08
# 2             hasYard  1.244705e-08
# 7   hasStormProtector  1.243823e-08
